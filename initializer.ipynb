# %%
# Use this to load data from google drive (you must create a Data folder and fill it with kaggle content)
from google.colab import drive
drive.mount('/content/drive')
! ls
% cd /content/drive/'My Drive'
! pwd
! ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# drive  sample_data
# /content/drive/My Drive
# /content/drive/My Drive
# '110 Essay First Draft.gdoc'
# '110 Essay.gdoc'
# '121 Prelab.docx'
# '121 Prelab.gdoc'
# '1) LandauLifshitz-Mechanics.pdf'
# '2019 Code - Python 3.zip'
# '2019 Code Working Version - Python 3 - No Feedback.zip'
# '221 Review.gdoc'
# '2)LandauLifshitz-TheClassicalTheoryOfFields.pdf'
#  304.gdoc
# '310 Review Notes.gdoc'
# '3) LandauLifshitz-QuantumMechanics.pdf'
# '4) LandauLifshitz-RelativisticQuantumTheoryPart1.pdf'
# '5) LandauLifshitz-StatisticalPhysics.pdf'
#  633Meje.png
# '6) LandauLifshitz-FluidMechanics.pdf'
# '7) LandauLifshitz-TheoryOfElasticity.pdf'
# '8) LandauLifshitz-ElectrodynamicsOfContinuousMedia.pdf'
# 'Adams - Calculus_ A Complete Course 9th Edition c2018 txtbk.pdf'
# 'After Wednesday.gdoc'
# 'Another exam review doc.gdoc'
#  Astronomy.pdf
# 'Back to School.gdoc'
# 'Backup meta.gdoc'
# 'benton_2005_vertebrate palaeontology.pdf'
# 'Bicoid transcription factor problem.pdf'
# 'Biology 140 Presentation.gdoc'
# 'Biology 140 Presentation.gslides'
# 'Biology - Brenda Walpole, Ashby Merson-Davies and Leighton Dann - Cambridge 2011 .pdf'
# 'Biology - Course Companion - Andrew Allott and David Mindorff - Oxford 2014.pdf'
# 'Biology Exam Review.gdoc'
# 'Biology - Study Guide - Andrew Allott - Oxford 2014.pdf'
#  Booklet.pdf
# 'Break Plans.gdoc'
#  Caernarfon.gdoc
#  Casimir.gdoc
#  Chadification.gdoc
# 'Chemistry Pre-lab.gdoc'
# 'Chem text abridged.pdf'
#  Circuitry.gdoc
# 'Classical Dynamics of Particles and Systems-Marion.pdf'
# 'Code fixes.gdoc'
# 'Colab Notebooks'
# 'Communist Cat backup.gsheet'
# 'Compair Draft.gdoc'
# 'Controversial opinion.gdoc'
# 'COOP 2: Electric Boogaloo.gdoc'
# 'Coop Applications (1).gdoc'
# 'Coop Applications.gdoc'
# 'Coop notes.gdoc'
# 'COOP Questions.gdoc'
# 'Copy of Script.gdoc'
# 'Copy of T2-Final Draft backup 2801.gdoc'
# 'Copy of T2-Final Draft Cut.gdoc'
# 'Copy of T2-Final Draft-Under word count, but not satisfied.gdoc'
# 'Copy of T2-Peer Review Draft Backup at 3500.gdoc'
# 'Copy of T2-Peer Review Draft.gdoc'
# 'Copy of Untitled document.gdoc'
#  Counter.gdoc
# 'Coupling and Cohesion.gdoc'
# 'Cover Letters.gdoc'
# 'CPSC 121.gdoc'
# 'CPSC 213.gdoc'
# 'CPSC 213 Review.gdoc'
# 'CPSC 221.gdoc'
# 'CPSC 221 Summary.gdoc'
# 'CPSC 310.gdoc'
# 'CPSC 310 Project (1).gdoc'
# 'CPSC 310 Project.gdoc'
# 'CPSC 320.gdoc'
#  CPSC340
# 'CPSC 340.gdoc'
# 'Cpsc again.gdoc'
# 'CPSC Cover Letter.gdoc'
#  CPSC.gdoc
# 'Daily Routine.gdoc'
#  Data
# 'DATA 2: Electric Boogaloo.gdoc'
#  DATA.gdoc
#  Data.gsheet
#  Datasets.gdoc
#  Decision.docs.gdoc
#  Decision.gdoc
# 'Development notes.gdoc'
# 'Dipole Notes.gdoc'
# 'Dipoles Sources (1).gdoc'
# 'Dipoles Sources.gdoc'
# 'Draft 2 Backup.gdoc'
# 'Draft 2.gdoc'
#  Draft.gdoc
# 'EE Draft Computer.gdoc'
# 'E.E. First Draft (1).gdoc'
# 'E.E. First Draft.docx'
# 'E.E. First Draft.gdoc'
#  Emails.gdoc
# 'English Bullshit.gdoc'
# 'English memes.gdoc'
# 'English Paper 2.gdoc'
# 'English Paper 3.gdoc'
# 'English Research Essay.gdoc'
# 'Eng Phys Email.gdoc'
#  EuclidCombinedContest.pdf
# 'Experiment 1.gdoc'
# 'Experiment 1 Week 1.gsheet'
# 'Facts and Logic.gdoc'
# 'Fall 2018 Prep.gdoc'
#  Feedback-Inhibition-diagrams.docx
#  Feedback-Inhibition-diagrams.docx.gdoc
#  FermatCombinedContest.pdf
# 'Final Draft.gdoc'
# 'Final Project.gdoc'
#  Finals.gdoc
# 'Finals Plan.gdoc'
# 'Finals Review Document.gdoc'
# 'Fixed Discussion.gdoc'
# 'Fix Paper.gdoc'
# 'Flying Wing.gdoc'
# 'Fucking essay.gdoc'
# 'FULL COMMUNISM.gdoc'
# 'Fusion Physics.pdf'
# 'GA (1).java'
#  GA.gdoc
#  GA.java
#  Genetics.gdoc
# 'George Martin - A Game of Thrones'
# 'Get your shit together.gdoc'
# 'Google Buzz'
# 'Group 4 ICCS Form - SWC version.pdf'
#  GUI.gdoc
# 'GUITAR SONGS.gdoc'
#  Heh
# 'Hehe xD.gdoc'
#  Heh.gdoc
# 'History Extended Essay.gdoc'
#  HitchhikingAcrossTheUniverse
# 'Hitchhiking logistics.gdoc'
# 'Howard is a dum.gdoc'
# 'How I met your discussion.gdoc'
#  ICL.gdoc
#  image.png
# 'Important Pickup Lines.gdoc'
# 'Interesting Things.gdoc'
# 'Interview Prep Again.gdoc'
# 'Interview prep.gdoc'
# 'Interview Prep.gdoc'
#  IROP.gdoc
# 'IROP Questions.gdoc'
# 'IROP Summary.gdoc'
# 'Is US backwards.gdoc'
#  iUROP_Trapping_Summer_Questions_2019.docx
#  iUROP_Trapping_Summer_Questions_2019.gdoc
#  iUROP_Trapping_Summer_Questions_2019.pdf
#  Java.gdoc
# 'John Taylor - Classical Mechanics .pdf'
# "Josh's Early Life Crisis.gdoc"
# "Josh's Get Rich Quick Plan.gdoc"
# "Josh's speedy tips for a lab well done.gdoc"
# 'Journal club notes.gdoc'
# 'Just Math Things.gdoc'
#  Knowledge.gdoc
# 'Knowledge Question.gslides'
# 'Lab 2.gdoc'
# 'La Langue et la Crise Syrienne.gslides'
# 'Last Bio lecture.gdoc'
# 'LAUNCH SYSTEMS.pdf'
#  Linear-Algebar-Klaus.pdf
#  Linuxer.gdoc
# 'Literature Review.gdoc'
# 'London Checklis.gdoc'
#  main.py
# 'Math 318.gdoc'
# 'Math Exam Review .gdoc'
# 'Math Exam Review .pdf'
# 'Matlab 2 Cancer.gdoc'
# 'MEMORIES (CONFIDENTIAL DO NOT OPEN).gdoc'
#  Memories.gdoc
# 'Meta Engineered Thinking Architecture.gdoc'
# 'Metaphysical Nonsense.gdoc'
# 'Methods and Results.gdoc'
# 'Midterm 2.gdoc'
#  Mixtape.gdoc
# 'Mixtape Notes.gdoc'
#  Model.gdoc
#  Modelling.gdoc
# 'Model plan.gdoc'
# 'More Lab Cancer.gdoc'
#  Movie_List_2016-10-10.xlsx
# 'My Plate.gdoc'
# 'My Saved Places (1).gmap'
# 'My Saved Places (2).gmap'
# 'My Saved Places.gmap'
#  Nevermore.gdoc
#  New.gdoc
#  oBfUsCaTiON.gdoc
# 'Optical Trapping Notes.gdoc'
#  Options.gdoc
# 'Orbital Mechanics for Engineering Students.pdf'
# 'Overview of the Red Queen hypothesis.gdoc'
#  PA1.gdoc
# 'Panel kms.gdoc'
# 'PascalCombinedContest (1).pdf'
#  PascalCombinedContest.pdf
# 'Penultimate Humdinger.gdoc'
# 'Peppers Assignment.gdoc'
# 'Personal philosophy.gdoc'
# 'Personal Statement January 2019.gdoc'
# 'PHYS 229'
# 'Physics Cover Letter.gdoc'
# 'Physics Exam Review .gdoc'
# 'Physics Midterm Review.gdoc'
#  Pines.gdoc
# 'Planning Document.gdoc'
# 'Planning T1.gdoc'
# 'Plans for "Break".gdoc'
# 'Presentation Planner.gdoc'
#  Procedure.gdoc
# 'Propagande Pub.gdoc'
# 'Quarter life bucket list.gdoc'
# 'Reading List.gdoc'
# 'Reading Plan.gdoc'
#  Reflections.gdoc
#  Reply.gdoc
# 'Respiration and photosynthesis worksheet.docx'
#  Resume1.docx
#  Resume1.docx.gdoc
# 'Rhetorical Fallacies.gdoc'
# 'R + J.gdoc'
# 'Rocket Propulsion Dynamics.pdf'
# 'Romeo and Juliet Essay Draft 1.gdoc'
#  sad.gdoc
# 'Safety Tests.gdoc'
# 'SARS 2: Electric Boogaloo.gdoc'
# 'Schedule Mania.gdoc'
# 'Script for Oral Discussion of Results.gdoc'
# 'Seminar Script.gdoc'
# 'Short Story Memes.gdoc'
# 'Should animal testing be prohibited.gdoc'
# "Side things that I'd like to do.gdoc"
# 'Snolab Application.gdoc'
# 'Solar Email .gdoc'
# 'Soup teaching.gdoc'
#  Special-Relativity.pdf
#  Squiggles.gdoc
#  SSC.gdoc
# 'Stupid fucking git commands.gdoc'
# 'Summer Things.gdoc'
#  -Sunday:.gdoc
# 'Synthèse Marivaux.docx'
# 'Synthèse Marivaux.docx.gdoc'
# 'T2-Final Draft.gdoc'
# 'T2 Fun.gdoc'
# 'T2 Presentation.gslides'
# 'T2 Proposal.gdoc'
# 'T2 Update.gdoc'
#  Tasklist.gdoc
#  Tennyson.mup
# 'The application cover sheet.gdoc'
# 'The Hitchhikers Guide to Everything I Guess.gdoc'
#  Theory-and-Reality-An-Introduction-to-the-Philosophy-of-Science.pdf
# 'The Pitch.gdoc'
# 'The Ultimate Humdinger (1).gdoc'
# 'The Ultimate Humdinger.gdoc'
#  Thing.gdoc
# "Things that everybody says they try to be, but actually don't.gdoc"
# 'Things That Go Bump in the Night.gdoc'
# "Things that Josh always says he's going to do when he has free time, but then never does.gdoc"
# 'Things to Calculate.gdoc'
# 'Things to do.gdoc'
# 'Things to do when I get back.gdoc'
# 'Things to learn.gdoc'
# 'Thunderstorm 1.wav'
# 'Thunderstorm 2.wav'
# 'Today (1).gdoc'
#  Today.gdoc
# '(todo (a b c)).gdoc'
# 'TOK Presentation.gslides'
# 'Tree Project.gdoc'
#  Trip.gdoc
# 'Trip Plan.gdoc'
# 'Trip references.gdoc'
#  Tropes.gdoc
#  Untitled4Copy2-checkpoint.ipynb
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'Urgent Humdinger.gdoc'
#  USRA.gdoc
# 'UwU (1).gdoc'
#  Uwu.gdoc
#  UwU.gdoc
#  UWU.gdoc
#  Vans.gdoc
# 'variational principles of mechanics lanczos.pdf'
# 'Vector Calculus.gdoc'
# 'very meta doc.gdoc'
# 'Vitamin C Assignment.gdoc'
# 'Vitamin C lab.gsheet'
# 'Wacht am Rhein (1).docx'
# 'Wacht am Rhein (1).docx.gdoc'
# 'Wacht am Rhein (2).docx.gdoc'
# 'Wacht am Rhein.docx'
# 'Wacht am Rhein.docx.gdoc'
#  Webcams.gdoc
# 'Weekend Things.gdoc'
# 'Week plans.gdoc'
# 'Worked Handout.gdoc'
# 'Worklist planning.gdoc'
# 'Worklist V 2.0.gdoc'
# 'XKCD 0-3.pdf'
#  Yeet.gdoc
#  Ye.gdoc
#  Y.gdoc

# %%
! mkdir "Jaminator"
! ls
# Out:
# '110 Essay First Draft.gdoc'
# '110 Essay.gdoc'
# '121 Prelab.docx'
# '121 Prelab.gdoc'
# '1) LandauLifshitz-Mechanics.pdf'
# '2019 Code - Python 3.zip'
# '2019 Code Working Version - Python 3 - No Feedback.zip'
# '221 Review.gdoc'
# '2)LandauLifshitz-TheClassicalTheoryOfFields.pdf'
#  304.gdoc
# '310 Review Notes.gdoc'
# '3) LandauLifshitz-QuantumMechanics.pdf'
# '4) LandauLifshitz-RelativisticQuantumTheoryPart1.pdf'
# '5) LandauLifshitz-StatisticalPhysics.pdf'
#  633Meje.png
# '6) LandauLifshitz-FluidMechanics.pdf'
# '7) LandauLifshitz-TheoryOfElasticity.pdf'
# '8) LandauLifshitz-ElectrodynamicsOfContinuousMedia.pdf'
# 'Adams - Calculus_ A Complete Course 9th Edition c2018 txtbk.pdf'
# 'After Wednesday.gdoc'
# 'Another exam review doc.gdoc'
#  Astronomy.pdf
# 'Back to School.gdoc'
# 'Backup meta.gdoc'
# 'benton_2005_vertebrate palaeontology.pdf'
# 'Bicoid transcription factor problem.pdf'
# 'Biology 140 Presentation.gdoc'
# 'Biology 140 Presentation.gslides'
# 'Biology - Brenda Walpole, Ashby Merson-Davies and Leighton Dann - Cambridge 2011 .pdf'
# 'Biology - Course Companion - Andrew Allott and David Mindorff - Oxford 2014.pdf'
# 'Biology Exam Review.gdoc'
# 'Biology - Study Guide - Andrew Allott - Oxford 2014.pdf'
#  Booklet.pdf
# 'Break Plans.gdoc'
#  Caernarfon.gdoc
#  Casimir.gdoc
#  Chadification.gdoc
# 'Chemistry Pre-lab.gdoc'
# 'Chem text abridged.pdf'
#  Circuitry.gdoc
# 'Classical Dynamics of Particles and Systems-Marion.pdf'
# 'Code fixes.gdoc'
# 'Colab Notebooks'
# 'Communist Cat backup.gsheet'
# 'Compair Draft.gdoc'
# 'Controversial opinion.gdoc'
# 'COOP 2: Electric Boogaloo.gdoc'
# 'Coop Applications (1).gdoc'
# 'Coop Applications.gdoc'
# 'Coop notes.gdoc'
# 'COOP Questions.gdoc'
# 'Copy of Script.gdoc'
# 'Copy of T2-Final Draft backup 2801.gdoc'
# 'Copy of T2-Final Draft Cut.gdoc'
# 'Copy of T2-Final Draft-Under word count, but not satisfied.gdoc'
# 'Copy of T2-Peer Review Draft Backup at 3500.gdoc'
# 'Copy of T2-Peer Review Draft.gdoc'
# 'Copy of Untitled document.gdoc'
#  Counter.gdoc
# 'Coupling and Cohesion.gdoc'
# 'Cover Letters.gdoc'
# 'CPSC 121.gdoc'
# 'CPSC 213.gdoc'
# 'CPSC 213 Review.gdoc'
# 'CPSC 221.gdoc'
# 'CPSC 221 Summary.gdoc'
# 'CPSC 310.gdoc'
# 'CPSC 310 Project (1).gdoc'
# 'CPSC 310 Project.gdoc'
# 'CPSC 320.gdoc'
#  CPSC340
# 'CPSC 340.gdoc'
# 'Cpsc again.gdoc'
# 'CPSC Cover Letter.gdoc'
#  CPSC.gdoc
# 'Daily Routine.gdoc'
#  Data
# 'DATA 2: Electric Boogaloo.gdoc'
#  DATA.gdoc
#  Data.gsheet
#  Datasets.gdoc
#  Decision.docs.gdoc
#  Decision.gdoc
# 'Development notes.gdoc'
# 'Dipole Notes.gdoc'
# 'Dipoles Sources (1).gdoc'
# 'Dipoles Sources.gdoc'
# 'Draft 2 Backup.gdoc'
# 'Draft 2.gdoc'
#  Draft.gdoc
# 'EE Draft Computer.gdoc'
# 'E.E. First Draft (1).gdoc'
# 'E.E. First Draft.docx'
# 'E.E. First Draft.gdoc'
#  Emails.gdoc
# 'English Bullshit.gdoc'
# 'English memes.gdoc'
# 'English Paper 2.gdoc'
# 'English Paper 3.gdoc'
# 'English Research Essay.gdoc'
# 'Eng Phys Email.gdoc'
#  EuclidCombinedContest.pdf
# 'Experiment 1.gdoc'
# 'Experiment 1 Week 1.gsheet'
# 'Facts and Logic.gdoc'
# 'Fall 2018 Prep.gdoc'
#  Feedback-Inhibition-diagrams.docx
#  Feedback-Inhibition-diagrams.docx.gdoc
#  FermatCombinedContest.pdf
# 'Final Draft.gdoc'
# 'Final Project.gdoc'
#  Finals.gdoc
# 'Finals Plan.gdoc'
# 'Finals Review Document.gdoc'
# 'Fixed Discussion.gdoc'
# 'Fix Paper.gdoc'
# 'Flying Wing.gdoc'
# 'Fucking essay.gdoc'
# 'FULL COMMUNISM.gdoc'
# 'Fusion Physics.pdf'
# 'GA (1).java'
#  GA.gdoc
#  GA.java
#  Genetics.gdoc
# 'George Martin - A Game of Thrones'
# 'Get your shit together.gdoc'
# 'Google Buzz'
# 'Group 4 ICCS Form - SWC version.pdf'
#  GUI.gdoc
# 'GUITAR SONGS.gdoc'
#  Heh
# 'Hehe xD.gdoc'
#  Heh.gdoc
# 'History Extended Essay.gdoc'
#  HitchhikingAcrossTheUniverse
# 'Hitchhiking logistics.gdoc'
# 'Howard is a dum.gdoc'
# 'How I met your discussion.gdoc'
#  ICL.gdoc
#  image.png
# 'Important Pickup Lines.gdoc'
# 'Interesting Things.gdoc'
# 'Interview Prep Again.gdoc'
# 'Interview prep.gdoc'
# 'Interview Prep.gdoc'
#  IROP.gdoc
# 'IROP Questions.gdoc'
# 'IROP Summary.gdoc'
# 'Is US backwards.gdoc'
#  iUROP_Trapping_Summer_Questions_2019.docx
#  iUROP_Trapping_Summer_Questions_2019.gdoc
#  iUROP_Trapping_Summer_Questions_2019.pdf
#  Jaminator
#  Java.gdoc
# 'John Taylor - Classical Mechanics .pdf'
# "Josh's Early Life Crisis.gdoc"
# "Josh's Get Rich Quick Plan.gdoc"
# "Josh's speedy tips for a lab well done.gdoc"
# 'Journal club notes.gdoc'
# 'Just Math Things.gdoc'
#  Knowledge.gdoc
# 'Knowledge Question.gslides'
# 'Lab 2.gdoc'
# 'La Langue et la Crise Syrienne.gslides'
# 'Last Bio lecture.gdoc'
# 'LAUNCH SYSTEMS.pdf'
#  Linear-Algebar-Klaus.pdf
#  Linuxer.gdoc
# 'Literature Review.gdoc'
# 'London Checklis.gdoc'
#  main.py
# 'Math 318.gdoc'
# 'Math Exam Review .gdoc'
# 'Math Exam Review .pdf'
# 'Matlab 2 Cancer.gdoc'
# 'MEMORIES (CONFIDENTIAL DO NOT OPEN).gdoc'
#  Memories.gdoc
# 'Meta Engineered Thinking Architecture.gdoc'
# 'Metaphysical Nonsense.gdoc'
# 'Methods and Results.gdoc'
# 'Midterm 2.gdoc'
#  Mixtape.gdoc
# 'Mixtape Notes.gdoc'
#  Model.gdoc
#  Modelling.gdoc
# 'Model plan.gdoc'
# 'More Lab Cancer.gdoc'
#  Movie_List_2016-10-10.xlsx
# 'My Plate.gdoc'
# 'My Saved Places (1).gmap'
# 'My Saved Places (2).gmap'
# 'My Saved Places.gmap'
#  Nevermore.gdoc
#  New.gdoc
#  oBfUsCaTiON.gdoc
# 'Optical Trapping Notes.gdoc'
#  Options.gdoc
# 'Orbital Mechanics for Engineering Students.pdf'
# 'Overview of the Red Queen hypothesis.gdoc'
#  PA1.gdoc
# 'Panel kms.gdoc'
# 'PascalCombinedContest (1).pdf'
#  PascalCombinedContest.pdf
# 'Penultimate Humdinger.gdoc'
# 'Peppers Assignment.gdoc'
# 'Personal philosophy.gdoc'
# 'Personal Statement January 2019.gdoc'
# 'PHYS 229'
# 'Physics Cover Letter.gdoc'
# 'Physics Exam Review .gdoc'
# 'Physics Midterm Review.gdoc'
#  Pines.gdoc
# 'Planning Document.gdoc'
# 'Planning T1.gdoc'
# 'Plans for "Break".gdoc'
# 'Presentation Planner.gdoc'
#  Procedure.gdoc
# 'Propagande Pub.gdoc'
# 'Quarter life bucket list.gdoc'
# 'Reading List.gdoc'
# 'Reading Plan.gdoc'
#  Reflections.gdoc
#  Reply.gdoc
# 'Respiration and photosynthesis worksheet.docx'
#  Resume1.docx
#  Resume1.docx.gdoc
# 'Rhetorical Fallacies.gdoc'
# 'R + J.gdoc'
# 'Rocket Propulsion Dynamics.pdf'
# 'Romeo and Juliet Essay Draft 1.gdoc'
#  sad.gdoc
# 'Safety Tests.gdoc'
# 'SARS 2: Electric Boogaloo.gdoc'
# 'Schedule Mania.gdoc'
# 'Script for Oral Discussion of Results.gdoc'
# 'Seminar Script.gdoc'
# 'Short Story Memes.gdoc'
# 'Should animal testing be prohibited.gdoc'
# "Side things that I'd like to do.gdoc"
# 'Snolab Application.gdoc'
# 'Solar Email .gdoc'
# 'Soup teaching.gdoc'
#  Special-Relativity.pdf
#  Squiggles.gdoc
#  SSC.gdoc
# 'Stupid fucking git commands.gdoc'
# 'Summer Things.gdoc'
#  -Sunday:.gdoc
# 'Synthèse Marivaux.docx'
# 'Synthèse Marivaux.docx.gdoc'
# 'T2-Final Draft.gdoc'
# 'T2 Fun.gdoc'
# 'T2 Presentation.gslides'
# 'T2 Proposal.gdoc'
# 'T2 Update.gdoc'
#  Tasklist.gdoc
#  Tennyson.mup
# 'The application cover sheet.gdoc'
# 'The Hitchhikers Guide to Everything I Guess.gdoc'
#  Theory-and-Reality-An-Introduction-to-the-Philosophy-of-Science.pdf
# 'The Pitch.gdoc'
# 'The Ultimate Humdinger (1).gdoc'
# 'The Ultimate Humdinger.gdoc'
#  Thing.gdoc
# "Things that everybody says they try to be, but actually don't.gdoc"
# 'Things That Go Bump in the Night.gdoc'
# "Things that Josh always says he's going to do when he has free time, but then never does.gdoc"
# 'Things to Calculate.gdoc'
# 'Things to do.gdoc'
# 'Things to do when I get back.gdoc'
# 'Things to learn.gdoc'
# 'Thunderstorm 1.wav'
# 'Thunderstorm 2.wav'
# 'Today (1).gdoc'
#  Today.gdoc
# '(todo (a b c)).gdoc'
# 'TOK Presentation.gslides'
# 'Tree Project.gdoc'
#  Trip.gdoc
# 'Trip Plan.gdoc'
# 'Trip references.gdoc'
#  Tropes.gdoc
#  Untitled4Copy2-checkpoint.ipynb
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'Urgent Humdinger.gdoc'
#  USRA.gdoc
# 'UwU (1).gdoc'
#  Uwu.gdoc
#  UwU.gdoc
#  UWU.gdoc
#  Vans.gdoc
# 'variational principles of mechanics lanczos.pdf'
# 'Vector Calculus.gdoc'
# 'very meta doc.gdoc'
# 'Vitamin C Assignment.gdoc'
# 'Vitamin C lab.gsheet'
# 'Wacht am Rhein (1).docx'
# 'Wacht am Rhein (1).docx.gdoc'
# 'Wacht am Rhein (2).docx.gdoc'
# 'Wacht am Rhein.docx'
# 'Wacht am Rhein.docx.gdoc'
#  Webcams.gdoc
# 'Weekend Things.gdoc'
# 'Week plans.gdoc'
# 'Worked Handout.gdoc'
# 'Worklist planning.gdoc'
# 'Worklist V 2.0.gdoc'
# 'XKCD 0-3.pdf'
#  Yeet.gdoc
#  Ye.gdoc
#  Y.gdoc

# %%
% cd ./Jaminator
! ls

# %%
# !git clone #REPO name
